# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfleft1= pd.read_csv('dim_claims.csv')
dfleft1
# Out:
#          dim_claim_id     bin drug  reject_code  pharmacy_claim_approved
# 0                   1  417380    A         75.0                        0
# 1                   2  999001    A          NaN                        1
# 2                   3  417740    A         76.0                        0
# 3                   4  999001    A          NaN                        1
# 4                   5  417740    A          NaN                        1
# ...               ...     ...  ...          ...                      ...
# 1335571       1335572  417740    C         75.0                        0
# 1335572       1335573  999001    C          NaN                        1
# 1335573       1335574  417380    C         70.0                        0
# 1335574       1335575  999001    C          NaN                        1
# 1335575       1335576  999001    C          NaN                        1
#
# [1335576 rows x 5 columns]

# %%
dfleft2= pd.read_csv('bridge.csv')
dfleft2
# Out:
#          dim_claim_id  dim_pa_id  dim_date_id
# 0                   1        1.0            1
# 1                   2        NaN            1
# 2                   3        2.0            1
# 3                   4        NaN            1
# 4                   5        NaN            1
# ...               ...        ...          ...
# 1335571       1335572   555950.0         1095
# 1335572       1335573        NaN         1095
# 1335573       1335574   555951.0         1095
# 1335574       1335575        NaN         1095
# 1335575       1335576        NaN         1095
#
# [1335576 rows x 3 columns]

# %%
dfright= pd.read_csv('dim_pa.csv')
dfright
# Out:
#         dim_pa_id  correct_diagnosis  tried_and_failed  contraindication  \
# 0               1                  1                 1                 0
# 1               2                  1                 0                 0
# 2               3                  0                 0                 1
# 3               4                  1                 1                 0
# 4               5                  0                 1                 0
# ...           ...                ...               ...               ...
# 555946     555947                  1                 0                 1
# 555947     555948                  1                 0                 1
# 555948     555949                  1                 1                 1
# 555949     555950                  1                 0                 0
# 555950     555951                  0                 0                 1
#
#         pa_approved
# 0                 1
# 1                 1
# 2                 1
# ...

# %%
merge1 = pd.merge(dfleft2, dfright, left_on= "dim_pa_id", right_on="dim_pa_id", how = "right")

# %%
print(merge1)
# Out:
#         dim_claim_id  dim_pa_id  dim_date_id  correct_diagnosis  \
# 0                  1        1.0            1                  1
# 1                  3        2.0            1                  1
# 2                 10        3.0            1                  0
# 3                 11        4.0            1                  1
# 4                 15        5.0            1                  0
# ...              ...        ...          ...                ...
# 555946       1335557   555947.0         1095                  1
# 555947       1335558   555948.0         1095                  1
# 555948       1335559   555949.0         1095                  1
# 555949       1335572   555950.0         1095                  1
# 555950       1335574   555951.0         1095                  0
#
#         tried_and_failed  contraindication  pa_approved
# 0                      1                 0            1
# 1                      0                 0            1
# ...

# %%
merge2 = pd.merge(dfleft1, merge1, left_on= "dim_claim_id", right_on="dim_claim_id", how = "right")

# %%
print(merge2)
# Out:
#         dim_claim_id     bin drug  reject_code  pharmacy_claim_approved  \
# 0                  1  417380    A         75.0                        0
# 1                  3  417740    A         76.0                        0
# 2                 10  417380    A         75.0                        0
# 3                 11  999001    A         76.0                        0
# 4                 15  417614    A         70.0                        0
# ...              ...     ...  ...          ...                      ...
# 555946       1335557  417380    C         70.0                        0
# 555947       1335558  417740    C         75.0                        0
# 555948       1335559  417740    C         75.0                        0
# 555949       1335572  417740    C         75.0                        0
# 555950       1335574  417380    C         70.0                        0
#
#         dim_pa_id  dim_date_id  correct_diagnosis  tried_and_failed  \
# ...

# %%
merge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 555951 entries, 0 to 555950
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   dim_claim_id             555951 non-null  int64
#  1   bin                      555951 non-null  int64
#  2   drug                     555951 non-null  object
#  3   reject_code              555951 non-null  float64
#  4   pharmacy_claim_approved  555951 non-null  int64
#  5   dim_pa_id                555951 non-null  float64
#  6   dim_date_id              555951 non-null  int64
#  7   correct_diagnosis        555951 non-null  int64
#  8   tried_and_failed         555951 non-null  int64
#  9   contraindication         555951 non-null  int64
#  10  pa_approved              555951 non-null  int64
# dtypes: float64(2), int64(8), object(1)
# memory usage: 50.9+ MB

# %%
merge2.head()
# Out:
#    dim_claim_id     bin drug  reject_code  pharmacy_claim_approved  dim_pa_id  \
# 0             1  417380    A         75.0                        0        1.0
# 1             3  417740    A         76.0                        0        2.0
# 2            10  417380    A         75.0                        0        3.0
# 3            11  999001    A         76.0                        0        4.0
# 4            15  417614    A         70.0                        0        5.0
#
#    dim_date_id  correct_diagnosis  tried_and_failed  contraindication  \
# 0            1                  1                 1                 0
# 1            1                  1                 0                 0
# 2            1                  0                 0                 1
# 3            1                  1                 1                 0
# 4            1                  0                 1                 0
#
#    pa_approved
# 0            1
# 1            1
# 2            1
# ...

# %%
df = merge2.drop(["dim_claim_id","dim_pa_id","dim_date_id", "pharmacy_claim_approved" ], axis= 1)

# %%
df.head()
# Out:
#       bin drug  reject_code  correct_diagnosis  tried_and_failed  \
# 0  417380    A         75.0                  1                 1
# 1  417740    A         76.0                  1                 0
# 2  417380    A         75.0                  0                 0
# 3  999001    A         76.0                  1                 1
# 4  417614    A         70.0                  0                 1
#
#    contraindication  pa_approved
# 0                 0            1
# 1                 0            1
# 2                 1            1
# 3                 0            1
# 4                 0            1

# %%
sns.countplot(x= 'pa_approved', data= df)
# Out:
# <AxesSubplot:xlabel='pa_approved', ylabel='count'>

# %%
sns.countplot(x= 'pa_approved', hue = 'bin', data= df)
# Out:
# <AxesSubplot:xlabel='pa_approved', ylabel='count'>

# %%
sns.countplot(x= 'pa_approved', hue = 'drug', data= df)
# Out:
# <AxesSubplot:xlabel='pa_approved', ylabel='count'>

# %%
sns.countplot(x= 'pa_approved', hue = 'reject_code', data= df)
# Out:
# <AxesSubplot:xlabel='pa_approved', ylabel='count'>

# %%
sns.countplot(x= 'pa_approved', hue = 'correct_diagnosis', data= df)
# Out:
# <AxesSubplot:xlabel='pa_approved', ylabel='count'>

# %%
sns.countplot(x= 'pa_approved', hue = 'tried_and_failed', data= df)
# Out:
# <AxesSubplot:xlabel='pa_approved', ylabel='count'>

# %%
sns.countplot(x= 'pa_approved', hue = 'contraindication', data= df)
# Out:
# <AxesSubplot:xlabel='pa_approved', ylabel='count'>

# %%
df = pd.get_dummies(df, columns= ['bin'])
df
# Out:
#        drug  reject_code  correct_diagnosis  tried_and_failed  \
# 0         A         75.0                  1                 1
# 1         A         76.0                  1                 0
# 2         A         75.0                  0                 0
# 3         A         76.0                  1                 1
# 4         A         70.0                  0                 1
# ...     ...          ...                ...               ...
# 555946    C         70.0                  1                 0
# 555947    C         75.0                  1                 0
# 555948    C         75.0                  1                 1
# 555949    C         75.0                  1                 0
# 555950    C         70.0                  0                 0
#
#         contraindication  pa_approved  bin_417380  bin_417614  bin_417740  \
# 0                      0            1           1           0           0
# ...

# %%
df = df.drop(['bin_999001'], axis =1)

df
# Out:
#        drug  reject_code  correct_diagnosis  tried_and_failed  \
# 0         A         75.0                  1                 1
# 1         A         76.0                  1                 0
# 2         A         75.0                  0                 0
# 3         A         76.0                  1                 1
# 4         A         70.0                  0                 1
# ...     ...          ...                ...               ...
# 555946    C         70.0                  1                 0
# 555947    C         75.0                  1                 0
# 555948    C         75.0                  1                 1
# 555949    C         75.0                  1                 0
# 555950    C         70.0                  0                 0
#
#         contraindication  pa_approved  bin_417380  bin_417614  bin_417740
# 0                      0            1           1           0           0
# ...

# %%
df = pd.get_dummies(df, columns= ['drug'])
df
# Out:
#         reject_code  correct_diagnosis  tried_and_failed  contraindication  \
# 0              75.0                  1                 1                 0
# 1              76.0                  1                 0                 0
# 2              75.0                  0                 0                 1
# 3              76.0                  1                 1                 0
# 4              70.0                  0                 1                 0
# ...             ...                ...               ...               ...
# 555946         70.0                  1                 0                 1
# 555947         75.0                  1                 0                 1
# 555948         75.0                  1                 1                 1
# 555949         75.0                  1                 0                 0
# 555950         70.0                  0                 0                 1
#
# ...

# %%
df = df.drop(['drug_C'], axis =1)

df
# Out:
#         reject_code  correct_diagnosis  tried_and_failed  contraindication  \
# 0              75.0                  1                 1                 0
# 1              76.0                  1                 0                 0
# 2              75.0                  0                 0                 1
# 3              76.0                  1                 1                 0
# 4              70.0                  0                 1                 0
# ...             ...                ...               ...               ...
# 555946         70.0                  1                 0                 1
# 555947         75.0                  1                 0                 1
# 555948         75.0                  1                 1                 1
# 555949         75.0                  1                 0                 0
# 555950         70.0                  0                 0                 1
#
# ...

# %%
df = pd.get_dummies(df, columns= ['reject_code'])
df
# Out:
#         correct_diagnosis  tried_and_failed  contraindication  pa_approved  \
# 0                       1                 1                 0            1
# 1                       1                 0                 0            1
# 2                       0                 0                 1            1
# 3                       1                 1                 0            1
# 4                       0                 1                 0            1
# ...                   ...               ...               ...          ...
# 555946                  1                 0                 1            0
# 555947                  1                 0                 1            1
# 555948                  1                 1                 1            1
# 555949                  1                 0                 0            1
# 555950                  0                 0                 1            0
#
# ...

# %%
df = df.drop(['reject_code_76.0'], axis =1)

df
# Out:
#         correct_diagnosis  tried_and_failed  contraindication  pa_approved  \
# 0                       1                 1                 0            1
# 1                       1                 0                 0            1
# 2                       0                 0                 1            1
# 3                       1                 1                 0            1
# 4                       0                 1                 0            1
# ...                   ...               ...               ...          ...
# 555946                  1                 0                 1            0
# 555947                  1                 0                 1            1
# 555948                  1                 1                 1            1
# 555949                  1                 0                 0            1
# 555950                  0                 0                 1            0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 555951 entries, 0 to 555950
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   correct_diagnosis  555951 non-null  int64
#  1   tried_and_failed   555951 non-null  int64
#  2   contraindication   555951 non-null  int64
#  3   pa_approved        555951 non-null  int64
#  4   bin_417380         555951 non-null  uint8
#  5   bin_417614         555951 non-null  uint8
#  6   bin_417740         555951 non-null  uint8
#  7   drug_A             555951 non-null  uint8
#  8   drug_B             555951 non-null  uint8
#  9   reject_code_70.0   555951 non-null  uint8
#  10  reject_code_75.0   555951 non-null  uint8
# dtypes: int64(4), uint8(7)
# memory usage: 44.9 MB

# %%
X = df.drop(['pa_approved'], axis =1)
X
# Out:
#         correct_diagnosis  tried_and_failed  contraindication  bin_417380  \
# 0                       1                 1                 0           1
# 1                       1                 0                 0           0
# 2                       0                 0                 1           1
# 3                       1                 1                 0           0
# 4                       0                 1                 0           0
# ...                   ...               ...               ...         ...
# 555946                  1                 0                 1           1
# 555947                  1                 0                 1           0
# 555948                  1                 1                 1           0
# 555949                  1                 0                 0           0
# 555950                  0                 0                 1           1
#
#         bin_417614  bin_417740  drug_A  drug_B  reject_code_70.0  \
# ...

# %%
y = df. pa_approved
y
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 555946    0
# 555947    1
# 555948    1
# 555949    1
# 555950    0
# Name: pa_approved, Length: 555951, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=111,
                                                    stratify=y)

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()

LR.fit(X_train, y_train)

y_pred = LR.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn import metrics
matrix = metrics.confusion_matrix(y_test, y_pred)
print(matrix)
# Out:
# [[19644 17264]
#  [ 8584 93496]]

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.8140271102541227

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT = DecisionTreeClassifier(criterion= 'entropy')

# %%
DT.fit(X_train, y_train)
y_pred = DT.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
matrix = metrics.confusion_matrix(y_test, y_pred)
print(matrix)

metrics.accuracy_score(y_test, y_pred)
# Out:
# [[18144 18764]
#  [ 7093 94987]]
# 0.8139623564624284

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(criterion= 'entropy', n_estimators= 100)


RF.fit(X_train, y_train)
y_pred = RF.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
matrix = metrics.confusion_matrix(y_test, y_pred)
print(matrix)

metrics.accuracy_score(y_test, y_pred)
# Out:
# [[18144 18764]
#  [ 7093 94987]]
# 0.8139623564624284
